# %%
from psychopy import visual, core, event, gui, data, sound
import pyglet
import numpy as np
import os
import pandas as pd
# Out:
# 2024-10-31 11:44:50.520 Python[12777:724973] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders/gy/41rdwfk96vzf3hw4dtyw03500000gn/T/org.python.python.savedState

# %%
display = pyglet.canvas.Display()
screen = display.get_default_screen()
screen
# Out:
# CocoaScreen(x=0, y=0, width=1920, height=1200)
